# %% [markdown]
# # 🛳️ Using ML To Predict Which Passeners Surrvived The Titanic Shipwreck!
#
# ## Problem Defination
# "what sorts of people were more likely to survive?” using passenger data (ie name, age, gender, socio-economic class, etc).
#
# ## Data
# > The Data For This Project was taken from :- https://www.kaggle.com/competitions/titanic/data
# * train.csv contains the training data for the model
# * test.csv contains the testing data on which the model is to be tested
# * gender_submission.csv is the format in which the predictions are to be submitted to Kaggle
#
# ## Evaluation
# The evaluation metric for this model is *accuracy*
# > For More Information, Check Out :- https://www.kaggle.com/competitions/titanic/overview/evaluation

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic/train.csv')
df.head().T
# Out:
#                                    0  \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                              1  \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# SibSp                                                        1
# Parch                                                        0
# Ticket                                                PC 17599
# Fare                                                   71.2833
# Cabin                                                      C85
# Embarked                                                     C
#
#                                   2  \
# PassengerId                       3
# Survived                          1
# Pclass                            3
# Name         Heikkinen, Miss. Laina
# Sex                          female
# Age                            26.0
# SibSp                             0
# Parch                             0
# Ticket             STON/O2. 3101282
# Fare                          7.925
# Cabin                           NaN
# Embarked                          S
#
#                                                         3  \
# PassengerId                                             4
# Survived                                                1
# Pclass                                                  1
# Name         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                female
# Age                                                  35.0
# SibSp                                                   1
# Parch                                                   0
# Ticket                                             113803
# Fare                                                 53.1
# Cabin                                                C123
# Embarked                                                S
#
#                                     4
# PassengerId                         5
# Survived                            0
# Pclass                              3
# Name         Allen, Mr. William Henry
# Sex                              male
# Age                              35.0
# SibSp                               0
# Parch                               0
# Ticket                         373450
# Fare                             8.05
# Cabin                             NaN
# Embarked                            S

# %%
df.size
# Out:
# 10692

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Cleaning The Data

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
def clean_data(df):
    df['Age'].fillna(df['Age'].median(), inplace=True)
    df.dropna(subset=['Embarked'], inplace=True)
    df.dropna(subset=['Cabin'], inplace=True)
    return df

# %%
train_df_clean = clean_data(df)
train_df_clean.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
train_df_clean.to_csv('titanic/train_clean.csv', index=False)

# %% [markdown]
# ## Encoding The Data
#
# Many features in this dataset are in text format. Hence, they need to be converted to numerical format before proceeding.

# %%
train_df_clean = pd.read_csv('titanic/train_clean.csv')

# %%
train_df_clean.head().T
# Out:
#                                                              0  \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# SibSp                                                        1
# Parch                                                        0
# Ticket                                                PC 17599
# Fare                                                   71.2833
# Cabin                                                      C85
# Embarked                                                     C
#
#                                                         1  \
# PassengerId                                             4
# Survived                                                1
# Pclass                                                  1
# Name         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                female
# Age                                                  35.0
# SibSp                                                   1
# Parch                                                   0
# Ticket                                             113803
# Fare                                                 53.1
# Cabin                                                C123
# Embarked                                                S
#
#                                    2                                3  \
# PassengerId                        7                               11
# Survived                           0                                1
# Pclass                             1                                3
# Name         McCarthy, Mr. Timothy J  Sandstrom, Miss. Marguerite Rut
# Sex                             male                           female
# Age                             54.0                              4.0
# SibSp                              0                                1
# Parch                              0                                1
# Ticket                         17463                          PP 9549
# Fare                         51.8625                             16.7
# Cabin                            E46                               G6
# Embarked                           S                                S
#
#                                     4
# PassengerId                        12
# Survived                            1
# Pclass                              1
# Name         Bonnell, Miss. Elizabeth
# Sex                            female
# Age                              58.0
# SibSp                               0
# Parch                               0
# Ticket                         113783
# Fare                            26.55
# Cabin                            C103
# Embarked                            S

# %%
train_df_clean.drop('Name', axis=1, inplace=True)

# %%
train_df_clean.head().T
# Out:
#                     0       1        2        3       4
# PassengerId         2       4        7       11      12
# Survived            1       1        0        1       1
# Pclass              1       1        1        3       1
# Sex            female  female     male   female  female
# Age              38.0    35.0     54.0      4.0    58.0
# SibSp               1       1        0        1       0
# Parch               0       0        0        1       0
# Ticket       PC 17599  113803    17463  PP 9549  113783
# Fare          71.2833    53.1  51.8625     16.7   26.55
# Cabin             C85    C123      E46       G6    C103
# Embarked            C       S        S        S       S

# %%
# Features to be converted - Sex, Ticket, Cabin, Embarked
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()

train_df_clean[['Sex', 'Ticket', 'Cabin', 'Embarked']] = encoder.fit_transform(train_df_clean[['Sex', 'Ticket', 'Cabin', 'Embarked']])

# %%
train_df_clean.head().T
# Out:
#                     0     1         2      3      4
# PassengerId    2.0000   4.0    7.0000   11.0  12.00
# Survived       1.0000   1.0    0.0000    1.0   1.00
# Pclass         1.0000   1.0    1.0000    3.0   1.00
# Sex            0.0000   0.0    1.0000    0.0   0.00
# Age           38.0000  35.0   54.0000    4.0  58.00
# SibSp          1.0000   1.0    0.0000    1.0   0.00
# Parch          0.0000   0.0    0.0000    1.0   0.00
# Ticket       123.0000  36.0   62.0000  134.0  31.00
# Fare          71.2833  53.1   51.8625   16.7  26.55
# Cabin         80.0000  54.0  128.0000  144.0  48.00
# Embarked       0.0000   2.0    2.0000    2.0   2.00

# %%
train_df_clean['Embarked'].value_counts()
# Out:
# 2.0    129
# 0.0     69
# 1.0      4
# Name: Embarked, dtype: int64

# %%
train_df_clean['Survived'].value_counts()
# Out:
# 1    134
# 0     68
# Name: Survived, dtype: int64

# %%
train_df_clean.corr()['Survived']
# Out:
# PassengerId    0.111985
# Survived       1.000000
# Pclass        -0.030513
# Sex           -0.545297
# Age           -0.228967
# SibSp          0.138202
# Parch          0.042456
# Ticket         0.062549
# Fare           0.128261
# Cabin          0.038628
# Embarked      -0.130910
# Name: Survived, dtype: float64

# %% [markdown]
# ## Modelling The Data

# %%
# taking only those features which have a +ve correlation with the target variable

X = train_df_clean[['PassengerId', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin']]
y = train_df_clean['Survived']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# using a basic Logistic Regressor model

from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()

logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report

logistic_y_preds = logreg.predict(X_test)

print(classification_report(y_test, logistic_y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        22
#            1       0.64      1.00      0.78        39
#
#     accuracy                           0.64        61
#    macro avg       0.32      0.50      0.39        61
# weighted avg       0.41      0.64      0.50        61
# c:\Users\MSI\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\MSI\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\MSI\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# pulling out the big guns
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_y_preds = model.predict(X_test)

print(classification_report(y_test, rf_y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        22
#            1       1.00      1.00      1.00        39
#
#     accuracy                           1.00        61
#    macro avg       1.00      1.00      1.00        61
# weighted avg       1.00      1.00      1.00        61

# %%
y_preds = model.predict(X)

print(classification_report(y, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.54      0.58        68
#            1       0.78      0.84      0.81       134
#
#     accuracy                           0.74       202
#    macro avg       0.71      0.69      0.70       202
# weighted avg       0.73      0.74      0.73       202

# %%
X.shape
# Out:
# (202, 6)

# %%
train_df_clean
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  Ticket     Fare  \
# 0              2         1       1  0.0  38.0      1      0   123.0  71.2833
# 1              4         1       1  0.0  35.0      1      0    36.0  53.1000
# 2              7         0       1  1.0  54.0      0      0    62.0  51.8625
# 3             11         1       3  0.0   4.0      1      1   134.0  16.7000
# 4             12         1       1  0.0  58.0      0      0    31.0  26.5500
# ..           ...       ...     ...  ...   ...    ...    ...     ...      ...
# 197          872         1       1  0.0  47.0      1      1    38.0  52.5542
# 198          873         0       1  1.0  33.0      0      0   102.0   5.0000
# 199          880         1       1  0.0  56.0      0      1    43.0  83.1583
# 200          888         1       1  0.0  19.0      0      0    10.0  30.0000
# 201          890         1       1  1.0  26.0      0      0     8.0  30.0000
#
#      Cabin  Embarked
# 0     80.0       0.0
# 1     54.0       2.0
# 2    128.0       2.0
# 3    144.0       2.0
# 4     48.0       2.0
# ..     ...       ...
# 197  101.0       2.0
# 198   33.0       2.0
# 199   69.0       0.0
# 200   29.0       2.0
# 201   59.0       0.0
#
# [202 rows x 11 columns]

# %% [markdown]
# ## Making Predictions on Test csv File

# %%
test_df = pd.read_csv('titanic/test.csv')
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

model.fit(X, y)
# Out:
# RandomForestClassifier()

# %%
test_clean = clean_data(test_df)

# %%
test_clean.isna().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
test_clean.drop('Name', axis=1, inplace=True)

# %%
test_clean.shape
# Out:
# (91, 10)

# %%
# Features to be converted - Sex, Ticket, Cabin, Embarked
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()

test_clean[['Sex', 'Ticket', 'Cabin', 'Embarked']] = encoder.fit_transform(test_clean[['Sex', 'Ticket', 'Cabin', 'Embarked']])

# %%
X = test_clean[['PassengerId', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin']]

# %%
X.shape
# Out:
# (91, 6)

# %%
y_preds = model.predict(X)

# %%
predicted_dict = {
    "PassengetId": test_clean['PassengerId'],
    "Survived": y_preds
}

predicted_df = pd.DataFrame(predicted_dict)

# %%
predicted_df
# Out:
#      PassengetId  Survived
# 12           904         1
# 14           906         1
# 24           916         1
# 26           918         1
# 28           920         1
# ..           ...       ...
# 404         1296         1
# 405         1297         1
# 407         1299         1
# 411         1303         1
# 414         1306         1
#
# [91 rows x 2 columns]

# %% [markdown]
# ## Redoing Everything - Because I'm An Idiot.

# %%
import numpy as np
import pandas as pd

# %%
training_df = pd.read_csv("titanic/train.csv")
training_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
testing_df = pd.read_csv('titanic/test.csv')
testing_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
training_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

def encodeData(df):
    encoder = OrdinalEncoder()
    df[['Sex', 'Ticket', 'Cabin', 'Embarked']] = encoder.fit_transform(df[['Sex', 'Ticket', 'Cabin', 'Embarked']])
    return df

# %%
training_df = encodeData(training_df)

# %%
training_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  1.0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0  38.0      1
# 2                               Heikkinen, Miss. Laina  0.0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0  35.0      1
# 4                             Allen, Mr. William Henry  1.0  35.0      0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila, Rev. Juozas  1.0  27.0      0
# 887                       Graham, Miss. Margaret Edith  0.0  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  0.0   NaN      1
# 889                              Behr, Mr. Karl Howell  1.0  26.0      0
# 890                                Dooley, Mr. Patrick  1.0  32.0      0
#
#      Parch  Ticket     Fare  Cabin  Embarked
# 0        0   523.0   7.2500    NaN       2.0
# 1        0   596.0  71.2833   81.0       0.0
# 2        0   669.0   7.9250    NaN       2.0
# 3        0    49.0  53.1000   55.0       2.0
# 4        0   472.0   8.0500    NaN       2.0
# ..     ...     ...      ...    ...       ...
# 886      0   101.0  13.0000    NaN       2.0
# 887      0    14.0  30.0000   30.0       2.0
# 888      2   675.0  23.4500    NaN       2.0
# 889      0     8.0  30.0000   60.0       0.0
# 890      0   466.0   7.7500    NaN       1.0
#
# [891 rows x 12 columns]

# %%
X = training_df[['PassengerId', 'SibSp', 'Parch', 'Ticket', 'Fare']]
y = training_df['Survived']

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

model.fit(X, y)
# Out:
# RandomForestClassifier()

# %%
testing_df['Fare'].fillna(testing_df['Fare'].median(), inplace=True)

# %%
testing_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
testing_df = encodeData(testing_df)

# %%
test_X = testing_df[['PassengerId', 'SibSp', 'Parch', 'Ticket', 'Fare']]

# %%
test_y_preds = model.predict(test_X)

# %%
submission_dict = {
    "PassengerId": testing_df['PassengerId'],
    "Survived": test_y_preds
}

submission_df = pd.DataFrame(submission_dict)

submission_df
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
submission_df.to_csv('titanic/submission1KshipraJadav.csv', index=False)

# %% [markdown]
# # Kaggle Score For Above Prediction - 0.6676 ~= 66%
